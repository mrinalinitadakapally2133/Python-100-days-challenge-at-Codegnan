# %%
lst=[1,2,3,4,5]
largest=lst[0]
for i in range(0, len(lst)):
    if largest<lst[i]:
        largest=lst[i]
print(largest)
# Out:
# 5

# %%
lst=[1,2,3,4,5]
count=0
for i in lst:
    count+=1
print(count)
# Out:
# 5

# %%
lst=[1,2,3,4,5]
largest=lst[0]
for i in range(0, len(lst)):
    if largest<lst[i]:
        largest=lst[i]
print(largest)
