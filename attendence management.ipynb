# %%
#get number of students in the class
n=int(input("Enter number of students in the class:"))
present_count = 0
absent_count = 0
for rollno in range(1,n+1): #rollno is variable
    print("Enter roll no student", rollno," is present or absent and select following option 1 or 2 \n 1.Present \n 2.Absent:")
    status=input()
    #check status
    if status=="1":
        present_count += 1
    elif status =="2":
        absent_count += 1
    else:
        print("Please select either 1 or 2 options")
print("Total students in the class:",n)
print("Number of students present:",present_count)
print("Number of students absent:",absent_count)
percentage=(present_count/n)*100
print("Attendence report:",percentage)
# Out:
# Enter number of students in the class: 10
# Enter roll no student 1  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  3
# Please select either 1 or 2 options
# Enter roll no student 2  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  1
# Enter roll no student 3  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  1
# Enter roll no student 4  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  1
# Enter roll no student 5  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  2
# Enter roll no student 6  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  2
# Enter roll no student 7  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  1
# Enter roll no student 8  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  1
# Enter roll no student 9  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  1
# Enter roll no student 10  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  2
# Total students in the class: 10
# Number of students present: 6
# Number of students absent: 3
# Attendence report: 60.0

# %%
#get number of students in the class
n=int(input("Enter number of students in the class:"))
present_count = 0
absent_count = 0
rollno = 1 #initialization
while rollno <= n: #condition
    print("Enter roll no", rollno," is present or absent and select following option 1 or 2 \n 1.Present \n 2.Absent:")
    status=input()
    #check status
    if status=="1":
        present_count += 1
        rollno +=1 #increment
    elif status =="2":
        absent_count += 1
        rollno +=1 #increment
    else:
        print("Please select either 1 or 2 options")
print("Total students in the class:",n)
print("Number of students present:",present_count)
print("Number of students absent:",absent_count)
percentage=(present_count/n)*100
print("Attendence report:",percentage)
# Out:
# Enter number of students in the class: 5
# Enter roll no 1  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  1
# Enter roll no 2  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  2
# Enter roll no 3  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  5
# Please select either 1 or 2 options
# Enter roll no 3  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  6
# Please select either 1 or 2 options
# Enter roll no 3  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  2
# Enter roll no 4  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  1
# Enter roll no 5  is present or absent and select following option 1 or 2
#  1.Present
#  2.Absent:
#  2
# Total students in the class: 5
# Number of students present: 2
# Number of students absent: 3
# Attendence report: 40.0
