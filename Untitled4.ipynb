# %%
# square of a number
# function defination
def squere(x):
    return x*x

assert squere(5) == 25 
print("Working fine")
# Out:
# Working fine

# %%
# square of a number
# function defination
def squere(x):
    return x*x

assetr squere(5) == 25 , "not equal"
print("Working fine")
# Out:
#   Cell In[10], line 6
#     assetr squere(5) == 25 , "not equal"
#            ^
# SyntaxError: invalid syntax

# %%
# Division of two numbers
a , b = 10 ,2
assert b>0, "Zero division not possiable"
print(a/b)
# Out:
# 5.0
