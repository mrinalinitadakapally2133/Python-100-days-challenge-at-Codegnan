# %%
# types of inheritance
# single heritance
# Parent class
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print("Animal makes a sound")


# Child class (single inheritance)
class Dog(Animal):
    def __init__(self, name, breed):
        super().__init__(name)
        self.breed = breed

    def speak(self):
        print(f"{self.name} says: Woof!")


# Object creation
d1 = Dog("Buddy", "Labrador")

# Method calls
print("Dog name:", d1.name)
print("Dog breed:", d1.breed)
d1.speak()
# Out:
# Dog name: Buddy
# Dog breed: Labrador
# Buddy says: Woof!

# %%
# types of inheritance
# multi level inheritance
class Person:
    def __init__(self, name):
        self.name = name

    def show_name(self):
        print("Name:", self.name)


# Parent class
class Employee(Person):
    def __init__(self, name, emp_id):
        super().__init__(name)
        self.emp_id = emp_id

    def show_employee(self):
        print("Employee ID:", self.emp_id)


# Child class
class Manager(Employee):
    def __init__(self, name, emp_id, department):
        super().__init__(name, emp_id)
        self.department = department

    def show_manager(self):
        print("Department:", self.department)


# Object creation
m1 = Manager("Ravi", 101, "IT")

# Method calls
m1.show_name()        # From Person
m1.show_employee()    # From Employee
m1.show_manager()     # From Manager
# Out:
# Name: Ravi
# Employee ID: 101
# Department: IT

# %%
# types of inheritance
# multiple inheritance
# Parent class 1
class Father:
    def __init__(self, father_name):
        self.father_name = father_name

    def show_father(self):
        print("Father Name:", self.father_name)


# Parent class 2
class Mother:
    def __init__(self, mother_name):
        self.mother_name = mother_name

    def show_mother(self):
        print("Mother Name:", self.mother_name)


# Child class (multiple inheritance)
class Child(Father, Mother):
    def __init__(self, father_name, mother_name, child_name):
        Father.__init__(self, father_name)
        Mother.__init__(self, mother_name)
        self.child_name = child_name

    def show_child(self):
        print("Child Name:", self.child_name)


# Object creation
c1 = Child("Ramesh", "Sita", "Arjun")

# Method calls
c1.show_father()
c1.show_mother()
c1.show_child()
# Out:
# Father Name: Ramesh
# Mother Name: Sita
# Child Name: Arjun

# %%
# types of inheritance
# Hierical inheritancere
# Parent class
class Vehicle:
    def __init__(self, brand):
        self.brand = brand

    def show_brand(self):
        print("Brand:", self.brand)


# Child class 1
class Car(Vehicle):
    def __init__(self, brand, model):
        super().__init__(brand)
        self.model = model

    def show_car(self):
        print("Car Model:", self.model)


# Child class 2
class Bike(Vehicle):
    def __init__(self, brand, bike_type):
        super().__init__(brand)
        self.bike_type = bike_type

    def show_bike(self):
        print("Bike Type:", self.bike_type)


# Object creation
car1 = Car("Toyota", "Innova")
bike1 = Bike("Yamaha", "Sports")

# Method calls
car1.show_brand()   # From Vehicle
car1.show_car()     # From Car

bike1.show_brand()  # From Vehicle
bike1.show_bike()   # From Bike
# Out:
# Brand: Toyota
# Car Model: Innova
# Brand: Yamaha
# Bike Type: Sports

# %%
# single inheritance
# parent class
class Manager:
    def __init__(self, name, employee_id, department):
        self.name = name
        self.employee_id = employee_id
        self.department = department
        
    def Manager_details(self):
        return f"My name is {self.name} and employee_id is {self.employee_id} and the department is {self.department}"
        
# child class
class Employee(Manager):
    def __int__(self, name, employee_id, department, email):
        super().__init__(name, employee_id, department)
        self.email = email
        
    def Employee_details(self):
        return f"My name is {self.name} and employee_id is {self.employee_id} and email_id is {self.email}"
        
m1 = Manager(name ="ravi", employee_id = 101, department = "Information Techolongy")
e1 = Employee(name ="shiva", employee_id = 121, department ="Information Techology", email = "shiva123@gmail.com")
print("Manager details is:", m1.manager_details())
print("Employee details is:", e1.employee_details())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 22
#      19         return f"My name is {self.name} and employee_id is {self.employee_id} and email_id is {self.email}"
#      21 m1 = Manager(name ="ravi", employee_id = 101, department = "Information Techolongy")
# ---> 22 e1 = Employee(name ="shiva", employee_id = 121, department ="Information Techology", email = "shiva123@gmail.com")
#      23 print("Manager details is:", m1.manager_details())
#      24 print("Employee details is:", e1.employee_details())
#
# TypeError: Manager.__init__() got an unexpected keyword argument 'email'

# %%
# types of inheritance
# multi level inheritance
class Person:
    def __init__(self, name):
        self.name = name

    def show_name(self):
        return f"Name:", self.name


# Parent class
class Employee(Person):
    def __init__(self, name, emp_id):
        super().__init__(name)
        self.emp_id = emp_id

    def show_employee(self):
        return f"Employee ID:", self.emp_id


# Child class
class Manager(Employee):
    def __init__(self, name, emp_id, department):
        super().__init__(name, emp_id)
        self.department = department

    def show_manager(self):
        print("Department:", self.department)



m1 = Manager("Ravi", 101, "IT")
m1.show_name()        
m1.show_employee()   
m1.show_manager()
# Out:
# Department: IT
